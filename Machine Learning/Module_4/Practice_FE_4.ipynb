# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import sklearn 
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer



data = {'score': [55, 58, 60, 62, 65, 65, 68, 70, 72, 75, 78, 80, 85, 90, 95, 98, 100, 100, 100, 15, 20]}
df = pd.DataFrame(data)
data1 = {'house_price':[30, 32, 35, 38, 40, 42, 45, 48, 50, 55, 60, 65, 70, 80, 90, 100, 120, 150, 200, 300, 400, 500, 800, 1000, 1200]}
df1 = pd.DataFrame(data1)

# %%
sns.histplot(data = df, x = 'score', bins = 60)
print('it is not normal cause it is skewed to the right and it has outliers at the left side and maximum value is gathered at 100')
# Out:
# it is not normal cause it is skewed to the right and it has outliers at the left side and maximum value is gathered at 100

# %%
# considering right skewed data,so we will use iqr method to find outliers

# %%
sns.kdeplot(data = df1, x = 'house_price')
# Out:
# <Axes: xlabel='house_price', ylabel='Density'>

# %%
# we can see that the data is right skewed and it has outliers at the right side and maximum value is gathered at 30 to 100
# so
